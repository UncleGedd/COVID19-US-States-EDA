# %% [markdown]
# # COVID-19 Predictors by State
# This notebook explores 22 predictors that could be useful for analyzing the COVID19 pandemic. The predictors are described in detail in the dataset's description.
#
# Whereas there has been much research into COVID19 as it affects nation states, this dataset focuses on individual states in the US, including the District of Columbia. The purpose of this notebook is to analyze the predictors themselves, not to create analytical models. This is due to the fact that COVID19 numbers (tests, infections, deaths) are updated constantly; thus, current models are preliminary and are trying to hit a moving target.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./COVID19_state.csv')
df.head()
# Out:
#         State  Tested  Infected  Deaths  Population  Pop Density    Gini  \
# 0      Alaska    3334       114     3.0      734002       1.2863  0.4081
# 1     Alabama    4755       830     4.0     4908621      96.9221  0.4847
# 2    Arkansas    3536       449     6.0     3038999      58.4030  0.4719
# 3     Arizona    1303       912    16.0     7378494      64.9550  0.4713
# 4  California   89600      4643   101.0    39937489     256.3727  0.4899
#
#    ICU Beds  Income Per Capita  GDP Per Capita  Unemployment  Sex Ratio  \
# 0       119              59687           73205           5.8   1.054688
# 1      1533              42334           45219           2.7   0.930145
# 2       732              42566           42454           3.5   0.956630
# 3      1559              43650           48055           4.5   0.966965
# 4      7338              62586           74205           3.9   0.975113
#
#    Smoking Rate  Flu Deaths  Respiratory Deaths  Physicians  Hospitals  \
# 0          21.0        12.1                35.3        1900         21
# 1          20.9        21.4                58.0       12205        101
# 2          22.3        18.0                61.7        7150         88
# 3          15.6        12.4                41.2       17806         83
# 4          11.3        15.6                30.9      112906        359
#
#    Health Spending  Pollution  Med-Large Airports  Avg Temp  Urban  Age 0-25  \
# 0            11064        6.4                 1.0      26.6   66.0      0.36
# 1             7281        8.1                 1.0      62.8   59.0      0.33
# 2             7408        7.1                 0.0      60.4   56.2      0.34
# 3             6452        9.7                 1.0      60.3   89.8      0.33
# 4             7549       12.8                 9.0      59.4   95.0      0.33
#
#    Age 26-54  Age 55+
# 0       0.39     0.25
# 1       0.37     0.31
# 2       0.37     0.30
# 3       0.36     0.30
# 4       0.40     0.26

# %% [markdown]
# ## Statistical Distributions

# %% [markdown]
# ## Grouping the Predictors

# %% [markdown]
# ## Correlations
