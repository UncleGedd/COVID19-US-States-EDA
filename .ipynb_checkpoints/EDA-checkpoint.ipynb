# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler
import xgboost as xgb
import statsmodels.api as sm
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('COVID19_state.csv')
df = df[df.State != 'District of Columbia']
df.head()
# Out:
#         State  Infected  Deaths  Tested    Gini  ICU Beds  Total Population  \
# 0     Alabama       639       4    4755  0.4847      1533           4850771
# 1      Alaska        85       1    3334  0.4081       119            738565
# 2     Arizona       665      15    1164  0.4713      1559           6809946
# 3    Arkansas       386       3    3398  0.4719       732           2977944
# 4  California      4914     102   89600  0.4899      7338          38982847
#
#     60plus  60plus per bed  60plus pct pop  ...  Sex Ratio  Smoking Rate  \
# 0  1065625         53854.0        0.219682  ...   0.930145          20.9
# 1   117047          6424.0        0.158479  ...   1.054688          21.0
# 2  1502688         21304.0        0.220661  ...   0.966965          15.6
# 3   655552         27536.0        0.220136  ...   0.956630          22.3
# 4  7292299         68758.0        0.187064  ...   0.975113          11.3
#
#    Median Age  Median Age M  Median Age F  Flu Deaths  Respiratory Deaths  \
# 0        38.9          37.4          40.3        21.4                58.0
# 1        34.0          33.6          34.5        12.1                35.3
# 2        37.4          36.1          38.7        12.4                41.2
# 3        37.9          36.6          39.3        18.0                61.7
# 4        36.3          35.2          37.5        15.6                30.9
#
#    Physicians  Hospitals  Pollution
# 0       12205        101        8.1
# 1        1900         21        6.4
# 2       17806         83        9.7
# 3        7150         88        7.1
# 4      112906        359       12.8
#
# [5 rows x 23 columns]

# %%
y_cases = df['Infected']
y_deaths = df['Deaths']
X = df[df.columns[3:]]

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
X_s = RobustScaler().fit_transform(X)

# %% [markdown]
# ## XGBoost

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)
xg_reg.fit(X_s, y_cases)
print('Score', xg_reg.score(X_s, y_cases))
# [print(c + '\t', f) for c,f in zip(X.columns, xg_reg.feature_importances_)]
plt.figure(figsize=(10,5))
plt.bar(X.columns, xg_reg.feature_importances_)
plt.xticks(fontsize=10, rotation=90)
plt.show()
# Out:
# Score 0.611800762521753

# %% [markdown]
# ## Regression

# %%
est = sm.OLS(y_cases, X_s)
est2 = est.fit()
print(est2.summary(xname=[*X.columns]))
# small pval, reject the null hypothesis that a feature has no effect
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Infected   R-squared (uncentered):                   0.813
# Model:                            OLS   Adj. R-squared (uncentered):              0.689
# Method:                 Least Squares   F-statistic:                              6.527
# Date:                Sun, 29 Mar 2020   Prob (F-statistic):                    2.75e-06
# Time:                        17:08:03   Log-Likelihood:                         -468.86
# No. Observations:                  50   AIC:                                      977.7
# Df Residuals:                      30   BIC:                                      1016.
# Df Model:                          20
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Tested              -193.5663    928.035     -0.209      0.836   -2088.867    1701.734
# Gini                3396.4785   1466.256      2.316      0.028     401.985    6390.972
# ICU Beds           -4230.5994   5562.594     -0.761      0.453   -1.56e+04    7129.733
# Total Population   -8886.2003   4363.017     -2.037      0.051   -1.78e+04      24.268
# 60plus              4882.1465   6974.816      0.700      0.489   -9362.328    1.91e+04
# 60plus per bed     -1795.3864   1809.287     -0.992      0.329   -5490.444    1899.671
# 60plus pct pop     -1802.8151   2381.215     -0.757      0.455   -6665.905    3060.275
# Income Per Capita  -4242.5609   2477.341     -1.713      0.097   -9301.966     816.844
# GDP per capita      3202.7402   2002.408      1.599      0.120    -886.721    7292.202
# Unemployment         317.4259   1012.856      0.313      0.756   -1751.101    2385.953
# Sex Ratio           -735.3307   2075.328     -0.354      0.726   -4973.715    3503.054
# Smoking Rate       -1430.8080   1642.281     -0.871      0.391   -4784.792    1923.176
# Median Age          3.561e+04   2.88e+04      1.235      0.226   -2.33e+04    9.45e+04
# Median Age M       -1.115e+04   1.65e+04     -0.676      0.504   -4.48e+04    2.25e+04
# Median Age F       -2.684e+04   1.63e+04     -1.646      0.110   -6.01e+04    6451.698
# Flu Deaths          -289.4776    810.612     -0.357      0.724   -1944.969    1366.013
# Respiratory Deaths  1741.7323   1499.456      1.162      0.255   -1320.565    4804.030
# Physicians          1.194e+04   3004.205      3.975      0.000    5805.337    1.81e+04
# Hospitals            130.2867   1920.388      0.068      0.946   -3791.670    4052.243
# Pollution          -2887.2883    964.724     -2.993      0.005   -4857.518    -917.058
# ==============================================================================
# Omnibus:                       14.652   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               57.941
# Skew:                          -0.292   Prob(JB):                     2.62e-13
# Kurtosis:                       8.241   Cond. No.                         215.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Random Forest

# %%
rfr = RandomForestRegressor(max_depth=3)
rfr.fit(X_s, y_cases)
print('score', rfr.score(X_s, y_cases), '\n')
plt.figure(figsize=(10,5))
plt.bar(X.columns, rfr.feature_importances_)
plt.xticks(fontsize=10, rotation=90)
plt.show()
# Out:
# score 0.8455290664766887

# %%
plt.scatter(df['Infected'], df['Tested'])

# %% [markdown]
# Idea! The predictors can be split into 2 groups. Don't compare flu deaths to gdp!
